# %% [markdown]
# # Instalación e importación de librerías

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ## Ruta de datos

# %%
path = os.path.join(os.getcwd(),'collecting_initial_data')
path_additional_data = os.path.join(path,'additional_data')
path_existing_data = os.path.join(path,'existing_data')

# %% [markdown]
# # Describing Data

# %% [markdown]
# **Cantidad de datos.** Para la mayoría de las técnicas de modelado, existen compensaciones asociadas con el tamaño de los datos. Grandes conjuntos de datos pueden producir modelos más precisos, pero también pueden alargar el tiempo de procesamiento. Considere si usar un subconjunto de datos es una posibilidad. Cuando tome notas para el informe final, asegúrese de incluir estadísticas de tamaño para todos los conjuntos de datos y recuerde considerar tanto la cantidad de registros como los campos (atributos) al describir los datos.

# %%
def amount_of_data(df):
    amount_of_data_list = []
    for col in df.columns:  
        amount_of_data_list.append(len(df[col][df[col].notnull()]))
    return amount_of_data_list

# %% [markdown]
# **Tipos de valor.** Los datos pueden tomar una variedad de formatos, como numérico, categórico (cadena) o booleano (verdadero/falso). Prestar atención al tipo de valor puede evitar problemas durante el modelado posterior.

# %%
def value_types(df):
    value_types_list = df.dtypes.values
    return value_types_list

# %% [markdown]
# **Esquemas de codificación.** Con frecuencia, los valores de la base de datos son representaciones de características como el género o el tipo de producto. Por ejemplo, un conjunto de datos puede usar M y F para representar hombres y mujeres, mientras que otro puede usar los valores numéricos 1 y 2. Tenga en cuenta cualquier esquema en conflicto en el informe de datos.

# %%
def coding_schemes(df):
    coding_schemes_list = df.iloc[0].values
    return coding_schemes_list

# %%
df_coec = pd.read_csv(os.path.join(path_additional_data,'costo_oferta_educacion_continua.csv'))

# %%
info_df_coec = pd.DataFrame(data=[df_coec.columns,amount_of_data(df_coec),value_types(df_coec),coding_schemes(df_coec)]).transpose()
info_df_coec = info_df_coec.rename(columns={0:'column_name',1:'amount_of_data',2:'value_types',3:'coding_schemes'})
info_df_coec
# Out:
#                      column_name amount_of_data value_types  \
# 0                              #             15     float64
# 1                    Universidad             15      object
# 2                         Ciudad             15      object
# 3                     Pagina Web             15      object
# 4                      Servicios            103      object
# 5               Tipos de Oferta             280      object
# 6             Areas de Formación            350      object
# 7       Nombre  de los Programas            519      object
# 8                      Modalidad            521      object
# 9                       horarios            521      object
# 10            Tiempo de duración            519      object
# 11             Duración programa            520      object
# 12                       Precio             518      object
# 13                formas de pago            521      object
# 14                 certificación            521      object
# 15  plataforma educacion virtual            521      object
# 16              Red de educación              1      object
#
#                                        coding_schemes
# 0                                                 1.0
# 1                   udla universidad de las americas
# 2                                               Quito
# 3        https://www.udla.edu.ec/educacion-continua2/
# 4   37 carreras de pregrado en modalidades presenc...
# 5                                           Maestrias
# 6                           Administracion y negocios
# 7                  gerencia de instituciones de salud
# 8                                         100% online
# 9                                 22 de marzo de 2021
# 10                                             1736 H
# 11                                     1 año  2 meses
# 12                                            llamar
# 13  efectivo , tarjetas de credito y , debito , ba...
# 14                   WACS, Acreditadora de Chile, CES
# 15                                 moodle ,office 365
# 16                                                NaN

# %% [markdown]
# # Explorando datos

# %%
df_coec.head()
# Out:
#      #                        Universidad Ciudad  \
# 0  1.0  udla universidad de las americas   Quito
# 1  NaN                                NaN    NaN
# 2  NaN                                NaN    NaN
# 3  NaN                                NaN    NaN
# 4  NaN                                NaN    NaN
#
#                                      Pagina Web  \
# 0  https://www.udla.edu.ec/educacion-continua2/
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#                                            Servicios Tipos de Oferta   \
# 0  37 carreras de pregrado en modalidades presenc...        Maestrias
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN       Diplomados
# 4                                                NaN              NaN
#
#           Areas de Formación                 Nombre  de los Programas  \
# 0  Administracion y negocios       gerencia de instituciones de salud
# 1                  Educacion                      liderazgo educativo
# 2                      Salud            seguridad y salud ocupacional
# 3  Administracion y negocios               administracion de empresas
# 4                        NaN  desarrollo de negocios y emprendimiento
#
#      Modalidad             horarios Tiempo de duración Duración programa  \
# 0  100% online  22 de marzo de 2021             1736 H    1 año  2 meses
# 1  100% online  22 de marzo de 2021             1680 H    1 año  2 meses
# 2  100% online  22 de marzo de 2021             1680 H    1 año  2 meses
# 3  100% online  22 de marzo de 2021              168 H         3-5 meses
# 4  100% online  22 de marzo de 2021              168 H         3-5 meses
#
#     Precio                                      formas de pago  \
# 0   llamar   efectivo , tarjetas de credito y , debito , ba...
# 1   llamar   efectivo , tarjetas de credito y , debito , ba...
# 2   llamar   efectivo , tarjetas de credito y , debito , ba...
# 3   llamar   efectivo , tarjetas de credito y , debito , ba...
# 4   llamar   efectivo , tarjetas de credito y , debito , ba...
#
#                       certificación plataforma educacion virtual  \
# 0  WACS, Acreditadora de Chile, CES           moodle ,office 365
# 1  WACS, Acreditadora de Chile, CES           moodle ,office 365
# 2  WACS, Acreditadora de Chile, CES           moodle ,office 365
# 3  WACS, Acreditadora de Chile, CES           moodle ,office 365
# 4  WACS, Acreditadora de Chile, CES           moodle ,office 365
#
#   Red de educación
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df_coec.describe(include='all')
# Out:
#                 #                        Universidad Ciudad  \
# count   15.000000                                 15     15
# unique        NaN                                 15     12
# top           NaN  udla universidad de las americas   Quito
# freq          NaN                                  1      4
# mean     8.000000                                NaN    NaN
# std      4.472136                                NaN    NaN
# min      1.000000                                NaN    NaN
# 25%      4.500000                                NaN    NaN
# 50%      8.000000                                NaN    NaN
# 75%     11.500000                                NaN    NaN
# max     15.000000                                NaN    NaN
#
#                                           Pagina Web  \
# count                                             15
# unique                                            15
# top     https://www.udla.edu.ec/educacion-continua2/
# freq                                               1
# mean                                             NaN
# std                                              NaN
# min                                              NaN
# 25%                                              NaN
# 50%                                              NaN
# 75%                                              NaN
# max                                              NaN
#
#                                                 Servicios  \
# count                                                 103
# unique                                                 15
# top     Cursos presenciales abiertos y cerrados,  inte...
# freq                                                   89
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                        Tipos de Oferta  Areas de Formación  \
# count                               280                350
# unique                               25                 53
# top     CURSOS Y PROGRAMAS DE FORMACION      Empresariales
# freq                                220                146
# mean                                NaN                NaN
# std                                 NaN                NaN
# min                                 NaN                NaN
# 25%                                 NaN                NaN
# 50%                                 NaN                NaN
# 75%                                 NaN                NaN
# max                                 NaN                NaN
#
#                  Nombre  de los Programas   Modalidad  \
# count                                 519         521
# unique                                503          10
# top     SQL Aplicado al Análisis de Datos  Presencial
# freq                                    2         151
# mean                                  NaN         NaN
# std                                   NaN         NaN
# min                                   NaN         NaN
# 25%                                   NaN         NaN
# 50%                                   NaN         NaN
# 75%                                   NaN         NaN
# max                                   NaN         NaN
#
#                                                  horarios Tiempo de duración  \
# count                                                 521                519
# unique                                                136                134
# top     Este curso se oferta bajo pedido, para grupos ...               16 H
# freq                                                   87                 46
# mean                                                  NaN                NaN
# std                                                   NaN                NaN
# min                                                   NaN                NaN
# 25%                                                   NaN                NaN
# 50%                                                   NaN                NaN
# 75%                                                   NaN                NaN
# max                                                   NaN                NaN
#
#        Duración programa   Precio   \
# count                520       518
# unique                99        76
# top                 32 H   llamar
# freq                  37       238
# mean                 NaN       NaN
# std                  NaN       NaN
# min                  NaN       NaN
# 25%                  NaN       NaN
# 50%                  NaN       NaN
# 75%                  NaN       NaN
# max                  NaN       NaN
#
#                                            formas de pago  \
# count                                                 521
# unique                                                 18
# top     DESCUENTOS\n10% de descuento por pronto pago: ...
# freq                                                  192
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                             certificación  \
# count                                                 521
# unique                                                 38
# top     Sistema nacional de Informacion, CES , Secreta...
# freq                                                  144
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        plataforma educacion virtual  \
# count                           521
# unique                           46
# top                   EPN , CEC-EPN
# freq                             99
# mean                            NaN
# std                             NaN
# min                             NaN
# 25%                             NaN
# 50%                             NaN
# 75%                             NaN
# max                             NaN
#
#                                          Red de educación
# count                                                   1
# unique                                                  1
# top     Red de Educación Continua de Latinoamérica y E...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
df_coec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   #                             15 non-null     float64
#  1   Universidad                   15 non-null     object
#  2   Ciudad                        15 non-null     object
#  3   Pagina Web                    15 non-null     object
#  4   Servicios                     103 non-null    object
#  5   Tipos de Oferta               280 non-null    object
#  6   Areas de Formación            350 non-null    object
#  7   Nombre  de los Programas      519 non-null    object
#  8   Modalidad                     521 non-null    object
#  9   horarios                      521 non-null    object
#  10  Tiempo de duración            519 non-null    object
#  11  Duración programa             520 non-null    object
#  12   Precio                       518 non-null    object
#  13  formas de pago                521 non-null    object
#  14  certificación                 521 non-null    object
#  15  plataforma educacion virtual  521 non-null    object
#  16  Red de educación              1 non-null      object
# dtypes: float64(1), object(16)
# memory usage: 69.3+ KB

# %% [markdown]
# ## Data Exploration Report

# %% [markdown]
# * ¿Qué tipo de hipótesis ha formulado acerca de los datos?: La hoja CSV esta compuesta de datos de cursos de eduación continúa con su información respectiva acerca de su ubicación, area, precio, modalidad, certificado, etc.
#
# * ¿Qué atributos parecen prometedores para un análisis posterior?: Los datos Modalidad, Areas de Formación, Nombre  de los Programas, Tiempo de duración y Precio.
#
# * ¿Sus exploraciones han revelado nuevas características sobre los datos?: Existen muchos datos nulos y datos erroneos que hay que corregir.
#
# * ¿Cómo han cambiado estas exploraciones su hipótesis inicial?: Se requerira un procesamiento de texto para identificar correctamente los datos.
#
# * ¿Puede identificar subconjuntos particulares de datos para su uso posterior?: Conjunto de datos conformada por Modalidad, Areas de Formación, Nombre  de los Programas, Tiempo de duración y Precio.
#
# * Eche otro vistazo a sus objetivos de minería de datos. ¿Esta exploración ha alterado los objetivos?: Estos datos son de vital importancia para obtener el valor de los cursos a nivel nacional

# %% [markdown]
# # Verificación de la calidad de los datos

# %% [markdown]
# **Datos faltantes**: incluye valores que están en blanco o codificados como falta de respuesta (como $null$, ? o 999).

# %%
mising_data_df_coec = amount_of_data(df_coec)
mising_data_df_coec
# Out:
# [15, 15, 15, 15, 103, 280, 350, 519, 521, 521, 519, 520, 518, 521, 521, 521, 1]

# %% [markdown]
# **Errores de datos**: suelen ser errores tipográficos cometidos al ingresar los datos.

# %%
#data_errors_df_coec 
def data_errors(df):
    data_errors_list = []
    for col in df.columns:  
        data_errors_list.append([df[col].value_counts()])
    return data_errors_list
data_errors(df_coec)
# Out:
# [[1.0     1
#   2.0     1
#   3.0     1
#   4.0     1
#   5.0     1
#   6.0     1
#   7.0     1
#   8.0     1
#   9.0     1
#   10.0    1
#   11.0    1
#   12.0    1
#   13.0    1
#   14.0    1
#   15.0    1
#   Name: #, dtype: int64],
#  [udla universidad de las americas                     1
#   uide universidad internacional del ecuador           1
#   universidad de los hemisferios                       1
#   utpl Universidad Pariticular de Loja                 1
#   Universidad Catolica de Santiago de Guayaquil        1
#   USFQ Universidad San Francisco de Quito              1
#   Universidad de Cuenca                                1
#   UNIB.E Universidad Iberoamericana del Ecuador        1
#    UTE Universidad Tecnológica Equinoccial             1
#   UNEMI Universidad Estatal de Milagro                 1
#   EPN Escuela Politecnica Nacional                     1
#   Universidad Catolica de Cuenca                       1
#   Escuela Superior Politecnica Litoral  ESPOL          1
#   universidad  estatal de Bolivar                      1
#   UPS UNIVERSIDAD POLITECNICA SALESIANA DEL ECUADOR    1
#   Name: Universidad, dtype: int64],
#  [Quito                                                                                             4
#   Quito Guayaquil Loja                                                                              1
#   Quito , Guaranda ,Ambato, Manta, Santa Elena , Santo Domingo ; Por toviejo , Babahoyo, Machala    1
#   Quito  , Guayaquil , Cuenca y Loja                                                                1
#   Guayaquil                                                                                         1
#   Cuenca                                                                                            1
#   Quito , Santo Domingo                                                                             1
#   Milagro , Guayas, Ecuador                                                                         1
#   Cuenca , Azogues ,Cañar y Machala                                                                 1
#   Guayaquil , Quito , Santa Elena                                                                   1
#   Guaranda                                                                                          1
#   Cuenca , Quito , Guayaquil                                                                        1
#   Name: Ciudad, dtype: int64],
#  [https://www.udla.edu.ec/educacion-continua2/                      1
#   https://www.uide.edu.ec/educacion-continua/                       1
#   https://educacioncontinua.uhemisferios.edu.ec/nuestros-cursos/    1
#   https://educacioncontinua.utpl.edu.ec/                            1
#   https://www.ucsg.edu.ec/educontinua/                              1
#   https://www.usfq.edu.ec/es/educacion-continua                     1
#   https://www.ucuenca.edu.ec/educacion-continua#                    1
#   https://www.unibe.edu.ec/educacion-continua/                      1
#   https://www.ute.edu.ec/tag/centro-de-educacion-continua/          1
#   https://www.unemi.edu.ec/index.php/educacion-continua-2/          1
#   https://www.cec-epn.edu.ec/                                       1
#   https://educacioncontinua.ucacue.edu.ec/                          1
#   http://www.ec.espol.edu.ec/                                       1
#   https://www.ueb.edu.ec                                            1
#   https://www.ups.edu.ec/formacion-continua                         1
#   Name: Pagina Web, dtype: int64],
#  [Cursos presenciales abiertos y cerrados,  interactivos, participativos y prácticos, de acuerdo con los requerimientos de nuestros clientes. Estamos regidos por normas de calidad internacionales y nos especializamos en varias ramas: tecnológicas, empresariales, educativas y sociales.\n\nCursos en modalidad virtual, abiertos y cerrados, rompen barreras de espacio y tiempo, ya que todo se realiza a través de la Internet. Impartimos formación en temáticas empresariales, tecnológicas, educativas y sociales.\n\nEn la Coordinación de Lingüística e Intercambios Culturales contamos con programas de enseñanza de  inglés, francés y mandarín, con más de 200 instructores. Contamos con la autorización para administrar el examen TOEFL®.                                                                                                                                                                                                                                                                                                                                                                    89
#   37 carreras de pregrado en modalidades presencial,  y semipresencial 22 diplomados en modalidad 100% online.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
#    más de 4 mil cursos temáticos y ,de especialización en 25 áreas                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
#   mas de 150 cursos tematicos y practicos en 6 areas                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
#   23 carreras en su Modalidad Presencial, 17 en su Modalidad Abierta y a Distancia y 5 postgrados vigentes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
#   cursos in house , programas tipo diplomado , diagnostico de necesidades , seminarios abiertos ,asesoria en capacitacion , diseño de propuesta de intervencion con modalidades precesiales y a distancia en grados y posgrados                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
#   ofrece una variedad de cursos y programas basados en el modelo educativo de las Artes Liberales, que, apoyados en una amplia oferta académica, actualizan y fortalecen conocimientos, destrezas y habilidades profesionales.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
#   Los cursos están enforcados a todas las áreas concretas al conocimiento con miras a perfeccionar destrezas aplicadas al desarrollo profesional.Areas de conocimiento: financiera/contable, desarrollo del talento humano, teconologías de la información, jurídica, proyectos, administrativa y gestión, social humanista, pedagógica, administración pública, entre otras.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
#   10% de docentes con título de Ph.D\n4 docentes realizando sus estudios de Doctorado.\n51% de docentes a tiempo completo.\nConvenios con instituciones nacionales y extranjeras.\nDepartamentos de Investigación.\nProyectos de investigación.\nDepartamento de proyectos de vinculación.\nProyectos vinculados a la comunidad.\nProgramas de becas con apoyo solidario, culturales, deportivos, excelencia, acción afirmativa y otros.\nInternet wifi en todas las instalaciones.\nBiblioteca virtual al servicio de los docentes, estudiantes y público en general.\nSólida formación profesional.\nLaboratorios de última tecnología.\nGrupos culturales y deportivos.                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
#   Con el propósito de gestionar cursos, programas, talleres y seminarios complementarios a las carreras de posgrado, desde inicios del mes de septiembre la Universidad UTE cuenta con un Centro de Educación Continua que busca fortalecer los conocimientos de la comunidad educativa del país                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
#   La Dirección de Investigación y Posgrado, realiza programas de calidad que impulsan la especialización profesional, académica y de investigación, como una respuesta a las crecientes demandas que plantea la sociedad del conocimiento.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
#   Contribuimos al desarrollo del país y América Latina con nuestra oferta de diplomaturas y cursos cortos, diseñados y estructurados pensando en las necesidades de las organizaciones, los individuos y la sociedad actual.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
#   Capacitación abierta\nOfrecemos cursos y programas de especialización de corta duración como los diplomados nacionales e internacionales, implementados con nuestras facultades de ESPOL en alianza con universidades extranjeras y centros que están a la vanguardia en diversas áreas de conocimiento; además de cursos, talleres, eventos y conferencias al público en general. Tenemos modalidades presenciales y virtuales.\n\nCapacitación corporativa\nBrindamos servicios de capacitación exclusiva a empresas y organizaciones del sector público y privado, de acuerdo a sus necesidades. Nuestra gran capacidad politécnica nos permite ofrecer programas integrales que abordan desde habilidades esenciales hasta las más técnicas, mediante el uso de laboratorios y metodologías prácticas que fortalecen la formación en gestión de negocios.\n\nServicios de asesoría en capacitación\nDetectamos las necesidades de capacitación y elaboramos un diseño personalizado de acuerdo a los requerimientos específicos de tu empresa para que pueda implementar y ejecutar sus propios programas de formación.     1
#   Ser reconocida como el área que contribuye a mejorar la calidad de vida y el bienestar integral de los miembros de la comunidad universitaria. Con Ofertas Academicas de los posgrados y maestrias en las diferentes facultades                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
#   La Universidad Politécnica Salesiana es una institución con formacion continua con diferentes tipos de ofertas academicas                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
#   Name: Servicios, dtype: int64],
#  [CURSOS Y PROGRAMAS DE FORMACION               220
#   CURSOS PRESENCIAL                              21
#   Diplomados Presenciales                        12
#   PROGRAMAS                                       4
#   CURSOS                                          3
#   Maestrias                                       1
#   Cursos en Linea                                 1
#   Maestria                                        1
#   DIPLOMADOS VIRTUALES                            1
#   CURSOS ONLINE                                   1
#   Diplomado en Construccion Sostenible            1
#   Diplomado de Community Manager                  1
#   Programas anteriores                            1
#   Diplomados                                      1
#   Programas Abiertos                              1
#   SEMINARIOS                                      1
#   CURSOS NO ARREGLADOS                            1
#   CURSOS REGLADOS                                 1
#   PROGRAMAS O DIPLOMADOS                          1
#   Cursos Online                                   1
#   Certificados , Cursos y Programas               1
#   Cursos Abiertos Online  Coaching Asistido       1
#   Cursos de Capacitación con Aval UIDE-SETEC      1
#   Certificaciones por Competencias Laborales      1
#   CURSO                                           1
#   Name: Tipos de Oferta , dtype: int64],
#  [Empresariales                                   146
#   Tecnologicos                                     34
#   educativos                                       25
#   Gestion Empresarial                              12
#   Marketing y Turismo                               9
#   INGENIERIA Y PROCESOS                             8
#   Tecnicos                                          8
#   Tecnologia e Innovacion                           7
#   Salud                                             7
#   facultad de Ciencias de la Educacion              6
#   facultad de cienciasadministrativas               6
#   Administracion                                    5
#   TECNOLOGIA                                        5
#   AutoEstudio                                       5
#   Educacion                                         5
#   Idiomas                                           5
#   Faculta de Jurisprudencia ,  Ciencias             4
#   TICS                                              4
#   CIENCIAS                                          3
#   facultad  de Ciencias Agropecuarias               3
#   EDUCACION                                         3
#   ADMINISTRACION                                    3
#   facultad ciencias ce la salud                     3
#   TECNOLOGIA E INNOVACION                           2
#   SALUD                                             2
#   Administracion y negocios                         2
#   Tecnologia                                        2
#   Docencia                                          1
#   Finanzas, Comercio y Ventas                       1
#   SOCIAL                                            1
#   TECNICO                                           1
#   Tecnologia e informacion                          1
#   Certificaciones                                   1
#   Bioseguridad                                      1
#   Seguridad                                         1
#   Comunicación                                      1
#   Gastronomia                                       1
#   Mecanica Automotriz                               1
#   Desarrollo Personal                               1
#   Tecnología de la Información y Comunicación       1
#   Administración y Legislación\n                    1
#   Ingenieria Civil                                  1
#    Tecnología de la Información y Comunicación      1
#   Formacion Docente                                 1
#   Negocios y Administracion                         1
#   Derecho                                           1
#   Trabajo Social                                    1
#   Financiero                                        1
#   WEBINARIOS                                        1
#   Marketing                                         1
#   Politica                                          1
#   Arte                                              1
#   AGRONOMO                                          1
#   Name: Areas de Formación, dtype: int64],
#  [SQL Aplicado al Análisis de Datos                                        2
#   Análisis Estadístico con SPSS Básico e Intermedio                        2
#   Fundamentos de Scrum aplicados a proyectos de desarrollo de software.    2
#   Estadística para la Toma de Decisiones                                   2
#   Programa de Especialización para Administrador de Restaurantes           2
#                                                                           ..
#   Didáctica y Metodología para llegar a los estudiantes                    1
#   CONVERSATION CLUB- INGLÉS                                                1
#   FRANCES                                                                  1
#   INGLES                                                                   1
#   Agricultura Urbana                                                       1
#   Name: Nombre  de los Programas, Length: 503, dtype: int64],
#  [Presencial                    151
#   VIRTUAL                       130
#   online                         85
#   EN VIVO                        45
#   presencial                     44
#   100% online                    25
#   online y autoinstruccional     16
#   ON LINE                        16
#   Semipresencial                  5
#   presencial y online             4
#   Name: Modalidad, dtype: int64],
#  [Este curso se oferta bajo pedido, para grupos e instituciones públicas o privada     87
#   Confirmación en proceso. ¡Comunicate con nosotros!                                   65
#   Este curso se oferta bajo pedido, para grupos e instituciones públicas o privadas    53
#   22 de marzo de 2021                                                                  25
#   24 H 7 DIAS A LA SEMANA                                                              25
#                                                                                        ..
#   2/2/2021 de 27/02/2021                                                                1
#   16/3/2021 de 29/04/2021                                                               1
#   Sábado 10h00-12h00 y 14h00-16h00                                                      1
#   29 de Julio                                                                           1
#    Inicio 6 febrero - fin 27 marzo 2021                                                 1
#   Name: horarios, Length: 136, dtype: int64],
#  [16 H                        46
#   32 H                        43
#   120 H                       40
#   48 H                        30
#   24 H                        30
#                               ..
#   600 H                        1
#   144 H                        1
#   1 a 4 horas al dia           1
#   21/12/2020 a 07 mayo/21      1
#   Sábados de 08:00 a 11:00     1
#   Name: Tiempo de duración, Length: 134, dtype: int64],
#  [32 H                                                                      37
#   16 H                                                                      29
#   1 mes                                                                     27
#   1.5                                                                       25
#   3-5 meses                                                                 22
#                                                                             ..
#    3 dias Martes 27 de abril  - Sabado 28 de abril - Domingo 29 de abril     1
#   67                                                                         1
#   700                                                                        1
#   140 H                                                                      1
#   11 dias                                                                    1
#   Name: Duración programa, Length: 99, dtype: int64],
#  [ llamar      238
#    $-           31
#    $140.00      20
#    $60.00       16
#    $180.00      16
#               ...
#    $910.00       1
#    $660.00       1
#    $580.00       1
#    $990.00       1
#    $155.00       1
#   Name:  Precio , Length: 76, dtype: int64],
#  [DESCUENTOS\n10% de descuento por pronto pago: pagando dos días antes del inicio del curso.\n15% de descuento por pronto pago, grupos a partir de tres o más personas: pagando dos días antes del inicio del curso. Se emitirá una sola factura a nombre de una sola persona del grupo o de la institución auspiciante.\n15% de descuento por pronto pago, por cliente frecuente, personas que tomaron cursos durante los últimos seis meses: pagando dos días antes del inicio del curso.\n50% de descuento a personas de la tercera edad.\nPersonas con carnet del CONADIS obtienen descuento, según el grado de discapacidad.\nFORMAS DE PAGO\n\nEl CEC-EPN pone a su disposición las siguientes formas de pago para la matriculación en los cursos de Educación Presencial:\n\nMatriculación Presencial en las oficinas de la Sede Medio Externo (Av. Toledo N23-55 y Madrid, Planta Baja), en el horario de 07:00 a 18:00 sin interrupción al medio día\n\nCon el formulario de inscripción que llene en Servicio al Cliente, usted puede cancelar en Tesorería:\n\nEn efectivo\nCheque certificado a nombre del CENTRO DE EDUCACIÓN CONTINUA EPN\nTarjetas de Débito VISA y Mastercard (Banco Guayaquil, Banco Pichincha)\nTarjetas de Crédito con pago corriente: VISA y MasterCard\nTarjetas de Crédito con pago corriente o diferido a tres meses sin intereses: Diners, Discover, VISA Banco Pichincha, Mastercard Banco Pichincha, VISA Banco del Pacífico y PACIFICARD; Visa, Mastercard Banco Guayaquil y American Express.\nMatriculación Online por medio del Portal en Línea (https://aps.cec-epn.edu.ec/)\n\nCon el Formulario de Pago de Matrícula impreso que emite el portal luego del proceso de Inscripción en el curso requerido, usted puede acercarse a cancelar en:\n\nLas sucursales del Banco Guayaquil (directamente a ventanilla sin llenar una papeleta).\nLas sucursales del Banco Pichincha (directamente a ventanilla sin llenar una papeleta).\nPichincha Mi Vecino\nAdemás, usted puede realizar los pagos con los datos del Formulario de Pago de Matrícula en:\n\nBanca Electrónica del Banco Pichincha, opción Pagos, Facturas No Inscritas, CENTRO DE EDUCACIÓN CONTINUA EPN.\nEn el Portal en Línea (https://aps.cec-epn.edu.ec/) con las Tarjetas de Crédito Diners, Discover, VISA Banco Pichincha y Mastercard Banco Pichincha, VISA Banco del Pacífico y PACIFICARD; American Express, Visa Y MasterCard de Banco Guayaquil. Con pago corriente o diferido a tres meses sin intereses.\n\nIMPORTANTE:\n\nUna vez que usted ha realizado el proceso de inscripción, debe imprimir el formato de pago respectivo. Cuando el curso tenga el cupo mínimo necesario, recibirá un correo de confirmación de apertura del curso a su dirección electrónica registrada.  Solo en ese momento usted debe  proceder a realizar el pago correspondiente desde la fecha que se le indique.    192
#   Cheque Certificado a nombre de ESPOL-TECH E.P.\nTarjeta de Débito/Crédito\nCorriente: Visa, Mastercard, Discover, American\nExpress y Diners Club.\nDiferido: Diners Club\nDepósito o Transferencia Bancaria\nRazón social: Empresa Pública de Servicios\nESPOLTECH E.P.\nRUC: 0968592010001\nCta. Cte. Banco Pacífico: #7427786\nCta. Cte. Banco Guayaquil: #1113864-0\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      68
#   efectivo , tarjetas de credito y , debito , banco pichincha                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    47
#   Pagos en Linea , Pagos sin tarjeta de Credito , Instituciones Financieras                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      36
#   PlacetoPay ,Transferencia bancaria o depósito\n Otras tarjetas de crédito\n Pagos directo al aliado                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            33
#   Gratis                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         25
#   DESCUENTOS \n10% de descuento por pronto pago\n20% de descuento a grupos de dos o más personas naturales\n20% de descuento a empresas que inscriban grupos de tres a más personas\n50% de descuento para personas de la tercera edad\nLas personas con el carnet del CONADIS poseen descuento, según el grado de discapacidad\nFORMAS DE PAGO\n\nEl CEC-EPN pone a su disposición las siguientes formas de pago para la matriculación en los cursos de Educación Virtual:\n\nMatriculación Presencial en las oficinas de la Sede Medio Externo (Av. Toledo N23-55 y Madrid, Planta Baja), en el horario de 8h00 a 13h00 y de 14h00 a 17h00\n\nCon el formulario de inscripción que llene en Servicio al Cliente, usted puede cancelar en Tesorería:\n\nEn efectivo\nCheque certificado a nombre del CENTRO DE EDUCACIÓN CONTINUA EPN\nTarjetas de Débito VISA y Mastercard (Banco Guayaquil, Banco Pichincha)\nTarjetas de Crédito con pago corriente: VISA y MasterCard\nTarjetas de Crédito con pago corriente o diferido a tres meses sin intereses: Diners, Discover, VISA Banco Pichincha, Mastercard Banco Pichincha, VISA Banco Pacífico y PACIFICARD; Visa, Mastercard Banco Guayaquil y American Express.\nMatriculación Online por medio del Portal en Línea (https://aps.cec-epn.edu.ec/)\n\nCon el Formulario de Pago de Matrícula impreso que emite el portal luego del proceso de Inscripción en el curso requerido, usted puede acercarse a cancelar en:\n\nLas sucursales del Banco de Guayaquil (directamente a ventanilla sin llenar una papeleta).\nLas sucursales del Banco del Pichincha (directamente a ventanilla sin llenar una papeleta).\nPichincha Mi Vecino\nAdemás, usted puede realizar los pagos con los datos del Formulario de Pago de Matrícula en:\n\nBanca Electrónica del Banco Pichincha, opción Pagos, Facturas No Inscritas, CENTRO DE EDUCACIÓN CONTINUA EPN.\nEn el Portal en Línea (https://aps.cec-epn.edu.ec/) con las Tarjetas de Crédito Diners, Discover, VISA Banco Pichincha y MasterCard Banco Pichincha, Visa Banco Pacífico y Pacificard; American Express, Visa Y MasterCard de Banco Guayaquil. Con pago corriente o diferido a tres meses sin intereses.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               24
# ...
#   Name: formas de pago, dtype: int64],
#  [Sistema nacional de Informacion, CES , Secretaria Tecnica del Sistema Nacional de  Cualificaciones Profesionales,SENECYT                                                                                      144
#   EPN, CEC-EPN Se entregará solamente , cuando el estudiante haya aprobado el curso                                                                                                                              96
#   Certificado de Aprobacion ESPOL FEN                                                                                                                                                                            34
#   Al finalizar el curso Ud. recibirá un certificado de aprobación avalado por la Escuela Politécnica Nacional. Para aprobar el curso debe obtener un mínimo del 73% en su calificación total.                    28
#   WACS, Acreditadora de Chile, CES                                                                                                                                                                               25
#   UNIVERSIDAD CATOLICA DE CUENCA                                                                                                                                                                                 25
#   certificacion universidad estatal de Bolivar                                                                                                                                                                   22
#   EPN, CEC-EPN Se entregará el certificado digital, cuando el estudiante haya aprobado el curso con un mínimo de 70/100 puntos.                                                                                  19
#   EPN, CEC-EPN Se entregará solamente cuando se haya aprobado el curso.                                                                                                                                          18
#   Certificado de Aprobacion ESPOL FEN - Pontificia Universidad Católica de Chile                                                                                                                                 13
#   CERTIFICADO UPS Universidad Politecnica Salesiana del Ecuador                                                                                                                                                  13
#   Certificado de Aprobacion ESPOL                                                                                                                                                                                11
#   la entrega de los certificados los realizará directamente INEPE (Instituto de Investigación, Educación y Promoción Popular del Ecuador). EPN, CEC-EPN                                                           9
#   Al finalizar el curso Ud. recibirá un certificado de aprobación avalado por la Escuela Politécnica Nacional.\n\nPara aprobar el curso debe obtener un mínimo del 73% en su calificación total                   7
#   EPN,CEC-EPN Se entregará el certificado digital, cuando el estudiante haya aprobado el curso con un mínimo de 70/100 puntos.                                                                                    7
#   EPN , CEC-EPN Se entregará solamente cuando se haya aprobado el curso.                                                                                                                                          6
#   Certificado de Aprobacion ESPOL FEN - UCHILE                                                                                                                                                                    6
#   EPN , CEC-EPN  \nUsted puede solicitar su certificado digital cancelando $30, después de aprobar el curso.                                                                                                      5
#   EPN, CEC-EPN Usted puede solicitar su certificado digital cancelando $30, después de aprobar el curso.                                                                                                          5
#   TRIPLE CERTIFICACION                                                                                                                                                                                            4
#   EPN, CURSOS DE IDIOMAS, CEC-EPN ,Certificados ISO 9001:2015!                                                                                                                                                    3
#   EPN , CEC-EPN   \nUsted puede solicitar su certificado digital cancelando $30, después de aprobar el curso.                                                                                                     2
#   EPN, CEC-EPN  Se entregará el certificado digital, cuando el estudiante haya aprobado el curso con un mínimo de 70/100 puntos.                                                                                  2
#   EPN , CEC-EPN Para la aprobación del curso el participante deberá obtener un mínimo de 70 puntos.                                                                                                               2
#   Certificado de Participacion ESPOL FEN                                                                                                                                                                          2
#   EPN,CEC-EPN                                                                                                                                                                                                     1
#   Certificado de Aprobacion ESPOL , FEN - UCHILE                                                                                                                                                                  1
#   Certificado de Aprobacion ESPOL FEN - MOCCA                                                                                                                                                                     1
#   EPN, CEC-EPN  Usted puede solicitar su certificado digital cancelando $30, después de aprobar el curso.                                                                                                         1
#   EPN,CEC-EPN Al finalizar el curso Ud. recibirá un certificado de aprobación avalado por la Escuela Politécnica Nacional.\n\nPara aprobar el curso debe obtener un mínimo del 73% en su calificación total.      1
#   EPN,CEC-EPN Se entregará solamente cuando se haya aprobado el curso.                                                                                                                                            1
#   EPN, CEC-EPN   Usted puede solicitar su certificado digital cancelando $30, después de aprobar el curso.                                                                                                        1
#   EPN, CEC-EPN Para la aprobación del curso el participante deberá obtener un mínimo de 70 puntos y asistir a los 2 encuentros presenciales.                                                                      1
#   EPN, CEC-EPN Para la aprobación del curso el participante deberá obtener un mínimo de 70 puntos.                                                                                                                1
#    \nEPN , CEC-EPN Para la aprobación del curso el participante deberá obtener un mínimo de 70 puntos.                                                                                                            1
#   EPN, CEC-EPN Se entregará el certificado digital, cuando el estudiante haya aprobado el curso con un mínimo de 70/100 puntos                                                                                    1
#   EPN , CEC-EPN Usted puede solicitar su certificado digital cancelando $30, después de aprobar el curso.                                                                                                         1
#   EPN, CEC-EPN  \nSe entregará el certificado digital, cuando el estudiante haya aprobado el curso con un mínimo de 70/100 puntos.                                                                                1
#   Name: certificación, dtype: int64],
#  [EPN , CEC-EPN                                                                                                                       99
#   sidweb                                                                                                                              68
#   ZOOM                                                                                                                                55
#   Microsoft Teams , READSPEAKER                                                                                                       36
#   Moodle (EVA)                                                                                                                        27
#   moodle ,office 365                                                                                                                  25
#   YOUTUBE                                                                                                                             25
#   EVEA                                                                                                                                22
#   Presencial                                                                                                                          17
#   Canvas UTPL                                                                                                                         14
#   moodle.uhemisferios.edu.ec                                                                                                          13
#   eVirtual Educación Continua                                                                                                         11
#    Moodle-Blackboard UIDE 24/7                                                                                                        10
#   Moodle , Entorno Virtual de Aprendizaje (EVA) ,en la modalidad b-learning                                                            9
#   MOOCs                                                                                                                                9
#   zoom                                                                                                                                 8
#   ZOOM / CHAT ASISTIDO                                                                                                                 7
#   ZOOM , AVAC                                                                                                                          7
#   Netacad                                                                                                                              6
#   EPN, CEC-EPN                                                                                                                         6
#   MOOC                                                                                                                                 6
#   ZOOM .AVAC                                                                                                                           5
#   Entorno Virtual de Enseñanza Aprendizaje ( EVEA)                                                                                     4
#   Moodle                                                                                                                               3
#   Teorico y Practico                                                                                                                   3
#   SGA Moodle.                                                                                                                          3
#    Edificio de Aulas y Relación con el Medio Externo (EARME).                                                                          3
#   TELEPRESENCIA VIDEOCONFERENCIA ZOOM                                                                                                  2
#   LMS, E-LEARNING, UTEOffice370                                                                                                        1
#   ZOOM .AVAC ,Uso de Software Fusión 360.                                                                                              1
#   Cyberteachers Platinum                                                                                                               1
#   Touchstone                                                                                                                           1
#   smart                                                                                                                                1
#   Moodle , (EVA)                                                                                                                       1
#   MOOCs ,Powtoon\nArdora\nHot Potatoes                                                                                                 1
#   LMS, E-LEARNING, UTEOffice365                                                                                                        1
#   LMS, E-LEARNING, UTEOffice371                                                                                                        1
#   LMS, E-LEARNING, UTEOffice366                                                                                                        1
#   LMS, E-LEARNING, UTEOffice367                                                                                                        1
#   Practico                                                                                                                             1
#   Trabajamos con textos de reconocida trayectoria internacional                                                                        1
#   LMS, E-LEARNING, UTEOffice368                                                                                                        1
#   LMS, E-LEARNING, UTEOffice369                                                                                                        1
#   LMS, E-LEARNING, UTEOffice373                                                                                                        1
#   LMS, E-LEARNING, UTEOffice372                                                                                                        1
#   Trabajamos con textos de reconocida  trayectoria internacional como la serie Interchange English for International Communication     1
#   Name: plataforma educacion virtual, dtype: int64],
#  [Red de Educación Continua de Latinoamérica y Europa  Red Global de Aprendizaje del Banco Mundial RECLA    1
#   Name: Red de educación, dtype: int64]]

# %% [markdown]
# **Errores de medición**: incluyen datos que se ingresaron correctamente pero que se basan en un esquema de medición incorrecto.

# %% [markdown]
# **Inconsistencias en la codificación**: generalmente involucran unidades de medida no estándar o inconsistencias de valores, como el uso de M y masculino para el género.

# %% [markdown]
# **Metadatos incorrectos**: incluyen discrepancias entre el significado aparente de un campo y el significado establecido en el nombre o la definición de un campo.

# %% [markdown]
# ### Data Quality Report

# %% [markdown]
# Según su exploración y verificación de la calidad de los datos, ahora está listo para preparar un informe que guiará la siguiente fase de CRISP-DM. Consulte el tema Verificación de la calidad de los datos para obtener más información.
#
# Lista de tareas
#
# Como se discutió anteriormente, hay varios tipos de problemas de calidad de datos. Antes de pasar al siguiente paso, tenga en cuenta los siguientes problemas de calidad y planifique una solución. Documente todas las respuestas en el informe de calidad de datos.
#
# * ¿Ha identificado atributos faltantes y campos en blanco? Si es así, ¿hay significado detrás de tales valores faltantes?
#
# * ¿Existen incoherencias ortográficas que puedan causar problemas en fusiones o transformaciones posteriores?
#
# * ¿Ha explorado las desviaciones para determinar si son "ruido" o fenómenos que vale la pena analizar más a fondo?
#
# * ¿Ha realizado una verificación de plausibilidad de los valores? Tome notas sobre cualquier conflicto aparente (como adolescentes con altos niveles de ingresos).
#
# * ¿Ha considerado excluir datos que no tienen impacto en sus hipótesis?
#
# * ¿Los datos se almacenan en archivos planos? Si es así, ¿los delimitadores son consistentes entre los archivos? ¿Cada registro contiene el mismo número de campos?

# %% [markdown]
# ## Consideraciones para el siguiente paso

# %% [markdown]
# Antes de preparar los datos para el modelado en IBM® SPSS® Modeler, considere los siguientes puntos:
#
# * ¿Qué tan bien entiendes los datos?
#
# * ¿Están claramente identificadas y accesibles todas las fuentes de datos? ¿Conoce algún problema o restricción?
#
# * ¿Ha identificado atributos clave de los datos disponibles?
#
# * ¿Te ayudaron estos atributos a formular hipótesis?
#
# * ¿Ha anotado el tamaño de todas las fuentes de datos?
#
# * ¿Es capaz de utilizar un subconjunto de datos cuando corresponda?
#
# * ¿Ha calculado estadísticas básicas para cada atributo de interés? ¿Emergió información significativa?
#
# * ¿Usó gráficos exploratorios para obtener más información sobre los atributos clave? ¿Esta idea reformuló alguna de sus hipótesis?
#
# * ¿Cuáles son los problemas de calidad de datos para este proyecto? ¿Tiene un plan para abordar estos problemas?
#
# * ¿Son claros los pasos de preparación de datos? Por ejemplo, ¿sabe qué fuentes de datos fusionar y qué atributos filtrar o seleccionar?
#
# Ahora que está armado con la comprensión de los datos y del negocio, es el momento de utilizar IBM SPSS Modeler para preparar sus datos para el modelado.
