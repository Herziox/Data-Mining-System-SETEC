# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import pandas as pd
import numpy as np
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Trabajo_de_Integracion_Curricular/CODE/DataWareHouse/CLEANED_DATA/'

# %%
os.listdir(path)
# Out:
# ['correos_corregidos.csv',
#  'main_phone_pcci.csv',
#  'cnc.csv',
#  'oc_cl.csv',
#  'pcoc.csv',
#  'doc_name_pcoc.csv',
#  'oec.csv',
#  'oec_dr.csv',
#  'pcoec.csv',
#  'ci.csv',
#  'ci_lca.csv',
#  'pcci.csv',
#  'doc_name_pcci.csv',
#  'provincia_canton_parroquia.xlsx',
#  '.ipynb_checkpoints',
#  'oc_cc.csv',
#  'oc.gsheet',
#  'oc.csv',
#  'OC_Area_Especialidad_Curso.csv',
#  'OEC_Familia_Sector_Perfil.csv',
#  'CI_Provincia_Canton.csv',
#  'OC_Familia_Sector_Perfil.csv',
#  'OEC_Provincia_Canton.csv',
#  'OC_Provincia_Canton.csv']

# %% [markdown]
# # Datawarehouse

# %%
path_datawarehouse = '/content/drive/MyDrive/Trabajo_de_Integracion_Curricular/CODE/DataWareHouse/'
path_datamart_oc = 'datamart_oc'
path_datamart_oec = 'datamart_oec'
path_datamart_ci = 'datamart_ci'

# %% [markdown]
#  ## Tabla Ubicacion

# %%
df_ubicacion = pd.ExcelFile(path+'provincia_canton_parroquia.xlsx')
df_ubicacion = pd.read_excel(df_ubicacion, 'canton')
df_ubicacion = df_ubicacion[['Código Cantón','Cantón','Provincia']].rename(columns={'Código Cantón':'id_ubicacion','Cantón':'canton','Provincia':'provincia'})
df_ubicacion.to_csv(path_datawarehouse+'/Ubicacion.csv',index=False)

# %% [markdown]
# # Dataframe OC

# %% [markdown]
# ## Tabla Razon Social OC

# %%
os.mkdir(path_datawarehouse+path_datamart_oc,0o666)

# %%
df_oc = pd.read_csv(path+'oc.csv')
df_razon_social_oc = df_oc[['Razon_Social','Estado','Canton']]
df_razon_social_oc=df_razon_social_oc.rename(columns={'Razon_Social':'nombre_oc','Canton':'canton'})
df_razon_social_oc = df_razon_social_oc.rename_axis('id_oc').reset_index().astype('object')
df_razon_social_oc.to_csv(path_datawarehouse+path_datamart_oc+'/'+'Razon_Social_OC.csv',index=False)
df_razon_social_oc = pd.merge(df_razon_social_oc,df_ubicacion,on='canton',how="left")
df_razon_social_oc.pop('id_ubicacion')
df_razon_social_oc = df_razon_social_oc.fillna({'provincia':'Sin Provincia'})
df_razon_social_oc.to_csv(path_datawarehouse+path_datamart_oc+'/Razon_Social_OC.csv',index=False)
df_razon_social_oc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 709 entries, 0 to 708
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id_oc      709 non-null    object
#  1   nombre_oc  709 non-null    object
#  2   Estado     709 non-null    object
#  3   canton     709 non-null    object
#  4   provincia  709 non-null    object
# dtypes: object(5)
# memory usage: 33.2+ KB

# %% [markdown]
# ## Tabla Curso_Perfil

# %% [markdown]
# ### Data Downloaded

# %%
df_oc_cc = pd.read_csv(path+'OC_Area_Especialidad_Curso.csv')
df_oc_cl = pd.read_csv(path+'OC_Familia_Sector_Perfil.csv')
df_oc_ug = pd.read_csv(path+'OC_Provincia_Canton.csv')
print('ug',len(df_oc_ug['Nombre'].unique()))
print('cc',len(df_oc_cc['Nombre'].unique()))
print('cl',len(df_oc_cl['Nombre'].unique()))
print('cl+cc',len((pd.concat([df_oc_cc['Nombre'],df_oc_cl['Nombre']])).unique()))
# Out:
# ug 547
# cc 541
# cl 71
# cl+cc 546

# %% [markdown]
# ### Web Scrapping

# %%
ext_oc_cc = pd.read_csv(path+'oc_cc.csv')[['Razon_Social','Curso','Especialidad','Area','Carga Horaria','Modalidad']]
ext_oc_cc['tipo'] = 'curso'
ext_oc_cl = pd.read_csv(path+'oc_cl.csv')[['Razon_Social','Perfil','Sector','Familia']]
ext_oc_cl['carga_horaria'] = np.NaN
ext_oc_cl['modalidad'] = np.NaN
ext_oc_cl['tipo'] = 'perfil'
data_curso_perfil = np.concatenate((ext_oc_cc.values,ext_oc_cl.values), axis=0)
df_curso_perfil = pd.DataFrame(data=data_curso_perfil,columns=['Razon_Social','curso_perfil','especialidad_sector','area_familia','carga_horaria','modalidad','tipo'])
df_curso_perfil.insert(0,'tipo',df_curso_perfil.pop('tipo'))
df_curso_perfil = df_curso_perfil.rename_axis('id_curso_perfil').reset_index().astype('object')
df_curso_perfil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2440 entries, 0 to 2439
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_curso_perfil      2440 non-null   object
#  1   tipo                 2440 non-null   object
#  2   Razon_Social         2440 non-null   object
#  3   curso_perfil         2440 non-null   object
#  4   especialidad_sector  2440 non-null   object
#  5   area_familia         2440 non-null   object
#  6   carga_horaria        2362 non-null   object
#  7   modalidad            2362 non-null   object
# dtypes: object(8)
# memory usage: 152.6+ KB

# %%
df_curso_perfil.to_csv(path_datawarehouse+path_datamart_oc+'/Curso_Perfil.csv',index=False)

# %% [markdown]
# ## Tabla de Hechos

# %%
df_pcoc = pd.read_csv(path+'pcoc.csv')
df_demanda_oc = df_pcoc.groupby(['Razon_Social_OC','Nombre_Curso_Perfil']).count().reset_index().iloc[:,:3]
df_demanda_oc = df_demanda_oc.rename(columns={'Numero_Documento':'num_cap_cer'})

# %%
df_demanda_oc = df_pcoc.groupby(['Razon_Social_OC','Nombre_Curso_Perfil']).count().reset_index().iloc[:,:3]
df_demanda_oc = df_demanda_oc.rename(columns={'Numero_Documento':'num_cap_cer'})
df_demanda_oc = pd.merge(df_demanda_oc,df_razon_social_oc,left_on=['Razon_Social_OC'],right_on=['nombre_oc'],how="left")
df_demanda_oc = pd.merge(df_demanda_oc,df_curso_perfil,left_on=['Razon_Social_OC','Nombre_Curso_Perfil'],right_on=['Razon_Social','curso_perfil'],how="left")
#df_demanda_oc = df_demanda_oc[['Razon_Social_OC','Razon_Social','nombre_oc','Estado','Nombre_Curso_Perfil','curso_perfil','num_cap_cer']]
df_demanda_oc = df_demanda_oc[['id_oc','id_curso_perfil','num_cap_cer']]
df_demanda_oc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4578 entries, 0 to 4577
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_oc            4055 non-null   object
#  1   id_curso_perfil  605 non-null    object
#  2   num_cap_cer      4578 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 143.1+ KB

# %%
df_demanda_oc.to_csv(path_datawarehouse+path_datamart_oc+'/Demanda_OC.csv',index=False)

# %% [markdown]
# # Dataframe OEC

# %%
os.mkdir(path_datawarehouse+path_datamart_oec,0o666)

# %% [markdown]
# ## Tabla Razon Social OEC

# %%
df_oec_extra = pd.read_csv(path+'OEC_Provincia_Canton.csv')
df_oec_extra
# Out:
#                                                 Nombre         Provincia  \
# 0                                    GWG S.A.S. B.I.C.             AZUAY
# 1                               GREEN WORK CONSULTORES             AZUAY
# 2    ASOCIACION DE CORREDORES DE BIENES RAICES ACBI...             AZUAY
# 3             EMPRESA ELECTRICA REGIONAL CENTRO SUR CA             AZUAY
# 4             CAMARA DE LA PEQUEÑA INDUSTRIA DEL AZUAY             AZUAY
# ..                                                 ...               ...
# 237                    CORDOVA SUAREZ MANOLO ALEXANDER        TUNGURAHUA
# 238                       ABKREA INGENIERIA CIA. LTDA.        TUNGURAHUA
# 239                                        L'ESCOFFIER        TUNGURAHUA
# 240                              CECFECONSULTORES C.L.        TUNGURAHUA
# 241     INSTITUTO SUPERIOR TECNOLÓGICO DOCE DE FEBRERO  ZAMORA CHINCHIPE
#
#      Cantón
# 0    CUENCA
# 1    CUENCA
# 2    CUENCA
# 3    CUENCA
# 4    CUENCA
# ..      ...
# 237  AMBATO
# 238  AMBATO
# 239  AMBATO
# 240  AMBATO
# 241  ZAMORA
#
# [242 rows x 3 columns]

# %%
df_oec_2 = pd.DataFrame()
df_oec_2['razon_social_oec'] = df_oec_extra['Nombre']
df_oec_2['estado']='Desconocido'
df_oec_2['provincia']=df_oec_extra['Provincia']
df_oec_2['canton']=df_oec_extra['Cantón']
df_oec_2
# Out:
#                                       razon_social_oec       estado  \
# 0                                    GWG S.A.S. B.I.C.  Desconocido
# 1                               GREEN WORK CONSULTORES  Desconocido
# 2    ASOCIACION DE CORREDORES DE BIENES RAICES ACBI...  Desconocido
# 3             EMPRESA ELECTRICA REGIONAL CENTRO SUR CA  Desconocido
# 4             CAMARA DE LA PEQUEÑA INDUSTRIA DEL AZUAY  Desconocido
# ..                                                 ...          ...
# 237                    CORDOVA SUAREZ MANOLO ALEXANDER  Desconocido
# 238                       ABKREA INGENIERIA CIA. LTDA.  Desconocido
# 239                                        L'ESCOFFIER  Desconocido
# 240                              CECFECONSULTORES C.L.  Desconocido
# 241     INSTITUTO SUPERIOR TECNOLÓGICO DOCE DE FEBRERO  Desconocido
#
#             provincia  canton
# 0               AZUAY  CUENCA
# 1               AZUAY  CUENCA
# 2               AZUAY  CUENCA
# 3               AZUAY  CUENCA
# 4               AZUAY  CUENCA
# ..                ...     ...
# 237        TUNGURAHUA  AMBATO
# 238        TUNGURAHUA  AMBATO
# 239        TUNGURAHUA  AMBATO
# 240        TUNGURAHUA  AMBATO
# 241  ZAMORA CHINCHIPE  ZAMORA
#
# [242 rows x 4 columns]

# %%
df_oec = pd.read_csv(path+'oec.csv')
df_razon_social_oec = df_oec[['Razon_Social','Estado','Canton']]
df_razon_social_oec=df_razon_social_oec.rename(columns={'Razon_Social':'razon_social_oec','Canton':'canton','Estado':'estado'})

df_razon_social_oec.to_csv(path_datawarehouse+path_datamart_oec+'/'+'Razon_Social_OEC.csv',index=False)
df_razon_social_oec = pd.merge(df_razon_social_oec,df_ubicacion,on='canton',how="left")
df_razon_social_oec.pop('id_ubicacion')
df_razon_social_oec = df_razon_social_oec.fillna({'provincia':'Sin Provincia'})
df_razon_social_oec = pd.concat([df_razon_social_oec,df_oec_2])
df_razon_social_oec = df_razon_social_oec.drop_duplicates(subset=['razon_social_oec'], keep='last')
df_razon_social_oec = df_razon_social_oec.rename_axis('id_oec').reset_index().astype('object')
df_razon_social_oec.to_csv(path_datawarehouse+path_datamart_oec+'/razon_social_oec.csv',index=False)

# %% [markdown]
# ## Tabla Perfil

# %%
oec_dr = pd.read_csv(path+'oec_dr.csv')
oec_dr
# Out:
#       RUC_o_Codigo                                       Razon_Social  \
# 0    1801742642001                       NAVAS ESCOBAR FAUSTO ENRIQUE
# 1    1801742642001                       NAVAS ESCOBAR FAUSTO ENRIQUE
# 2    0992864753001                                    SESOCORPSA S.A.
# 3    1793005489001       ESCUELA PROFESIONAL Y TECNICA CODADEPRO C.A.
# 4    1793005489001       ESCUELA PROFESIONAL Y TECNICA CODADEPRO C.A.
# ..             ...                                                ...
# 992  0591755080001  COOPERACIÓN Y RESPALDO PARA LA EDUCACIÓN COORE...
# 993  0591755080001  COOPERACIÓN Y RESPALDO PARA LA EDUCACIÓN COORE...
# 994  0591755080001  COOPERACIÓN Y RESPALDO PARA LA EDUCACIÓN COORE...
# 995  0160001240001                              UNIVERSIDAD DE CUENCA
# 996  0603549825001                    VINUEZA TAPIA KATHERINE STEFANY
#
#                               Perfil         Esquema_de_Certificacion
# 0                 ASESORÍA DE IMAGEN               ASESORÍA DE IMAGEN
# 1                         MAQUILLAJE                       MAQUILLAJE
# 2                         Sin Perfil     Sin Esquema de Certificación
# 3         ADMINISTRACIÓN DE EMPRESAS       ADMINISTRACIÓN DE EMPRESAS
# 4    ARMADO DE ESTRUCTURAS METÁLICAS  ARMADO DE ESTRUCTURAS METÁLICAS
# ..                               ...                              ...
# 992               VENTA DE PRODUCTOS               COMERCIO MINORISTA
# 993               VENTA DE PRODUCTOS               VENTA EN MOSTRADOR
# 994               VENTA DE PRODUCTOS    VENTA Y DESPACHO DE PRODUCTOS
# 995                       Sin Perfil     Sin Esquema de Certificación
# 996                       MAQUILLAJE                       MAQUILLAJE
#
# [997 rows x 4 columns]

# %%
df_perfil = oec_dr[['Razon_Social','Perfil','Esquema_de_Certificacion']]
df_perfil = df_perfil.rename_axis('id_perfil').reset_index().astype('object')
len(oec_dr['Perfil'].unique())
# Out:
# 128

# %% [markdown]
# ### Downloaded Data

# %%
df_perfil = pd.read_csv(path+'OEC_Familia_Sector_Perfil.csv')
df_perfil = df_perfil.rename_axis('id_perfil').reset_index().astype('object')
df_perfil = df_perfil.rename(columns={'Perfil':'Perfil_Perfil','Nombre':'Perfil_Razon_Social_OEC'})
len(oec_dr['Perfil'].unique())
df_perfil.to_csv(path_datawarehouse+path_datamart_oec+'/perfil.csv',index=False)

# %% [markdown]
# ## Tabla Fecha

# %% [markdown]
# ## Tabla Hechos OEC

# %%
df_pcoec = pd.read_csv(path+'pcoec.csv')
df_demanda_oec = df_pcoec.groupby(['OEC','Perfil','Fecha_Certificacion']).count().reset_index().iloc[:,:4]
df_demanda_oec = df_demanda_oec.rename(columns={'Nombres':'num_cer'})
df_demanda_oec = pd.merge(df_demanda_oec,df_razon_social_oec,left_on=['OEC'],right_on=['razon_social_oec'],how="left")
df_demanda_oec
# Out:
#                                  OEC                                   Perfil  \
# 0      ABALCO HARO CRISTIAN PATRICIO               ASISTENCIA DE CONTABILIDAD
# 1      ABALCO HARO CRISTIAN PATRICIO               ASISTENCIA DE CONTABILIDAD
# 2      ABALCO HARO CRISTIAN PATRICIO               ASISTENCIA DE CONTABILIDAD
# 3      ABALCO HARO CRISTIAN PATRICIO               ASISTENCIA DE CONTABILIDAD
# 4      ABALCO HARO CRISTIAN PATRICIO               ASISTENCIA DE CONTABILIDAD
# ...                              ...                                      ...
# 48145        WINNING CONSULTORES S A          GESTIÓN ESPECIALIZADA EN VENTAS
# 48146        WINNING CONSULTORES S A          GESTIÓN ESPECIALIZADA EN VENTAS
# 48147        WINNING CONSULTORES S A                               MAQUILLAJE
# 48148        WINNING CONSULTORES S A  ORGANIZACIÓN Y GESTIÓN DE LA SECRETARIA
# 48149        WINNING CONSULTORES S A  ORGANIZACIÓN Y GESTIÓN DE LA SECRETARIA
#
#       Fecha_Certificacion  num_cer id_oec               razon_social_oec  \
# 0              01-06-2022        6     79  ABALCO HARO CRISTIAN PATRICIO
# 1              02-08-2022        1     79  ABALCO HARO CRISTIAN PATRICIO
# 2              04-04-2022        3     79  ABALCO HARO CRISTIAN PATRICIO
# 3              05-03-2022        4     79  ABALCO HARO CRISTIAN PATRICIO
# 4              06-02-2022        8     79  ABALCO HARO CRISTIAN PATRICIO
# ...                   ...      ...    ...                            ...
# 48145          28-02-2020        5    307        WINNING CONSULTORES S A
# 48146          29-02-2020        6    307        WINNING CONSULTORES S A
# 48147          17-02-2020        1    307        WINNING CONSULTORES S A
# 48148          03-02-2020        1    307        WINNING CONSULTORES S A
# 48149          20-11-2019        2    307        WINNING CONSULTORES S A
#
#                                     estado      canton      provincia
# 0                              Desconocido   GUAYAQUIL         GUAYAS
# 1                              Desconocido   GUAYAQUIL         GUAYAS
# 2                              Desconocido   GUAYAQUIL         GUAYAS
# 3                              Desconocido   GUAYAQUIL         GUAYAS
# 4                              Desconocido   GUAYAQUIL         GUAYAS
# ...                                    ...         ...            ...
# 48145  FINALIZO VIGENCIA DE RECONOCIMIENTO  Sin Cantón  Sin Provincia
# 48146  FINALIZO VIGENCIA DE RECONOCIMIENTO  Sin Cantón  Sin Provincia
# 48147  FINALIZO VIGENCIA DE RECONOCIMIENTO  Sin Cantón  Sin Provincia
# 48148  FINALIZO VIGENCIA DE RECONOCIMIENTO  Sin Cantón  Sin Provincia
# 48149  FINALIZO VIGENCIA DE RECONOCIMIENTO  Sin Cantón  Sin Provincia
#
# [48150 rows x 9 columns]

# %%
rhs = (df_demanda_oec.Perfil
          .apply(lambda x: df_perfil[df_perfil.Perfil_Perfil.str.find(x).ge(0)]['id_perfil'])
          .bfill(axis=1)
          .iloc[:, 0])

#df_demanda_oec = pd.merge(df_demanda_oec,df_perfil,left_on=['OEC','Perfil'],right_on=['Perfil_Razon_Social_OEC','Perfil_Perfil'],how="left")

# %%
df_res = pd.concat([df_demanda_oec, rhs], axis=1, ignore_index=True)
res_columns = df_demanda_oec.columns
res_columns = np.append(res_columns.values, 'id_perfil')
df_res = pd.DataFrame(data=df_res.values,columns=res_columns)

# %%
df_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48150 entries, 0 to 48149
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OEC                  48150 non-null  object
#  1   Perfil               48150 non-null  object
#  2   Fecha_Certificacion  48150 non-null  object
#  3   num_cer              48150 non-null  object
#  4   id_oec               47252 non-null  object
#  5   razon_social_oec     47252 non-null  object
#  6   estado               47252 non-null  object
#  7   canton               47252 non-null  object
#  8   provincia            47252 non-null  object
#  9   id_perfil            21590 non-null  object
# dtypes: object(10)
# memory usage: 3.7+ MB

# %%
df_demanda_oec = df_res[['id_oec','id_perfil','Fecha_Certificacion','num_cer']]

# %%
df_fecha = df_demanda_oec['Fecha_Certificacion'].drop_duplicates()
df_fecha = df_fecha.rename_axis('id_fecha').reset_index().astype('object')

# %%
df_demanda_oec = pd.merge(df_demanda_oec,df_fecha,left_on=['Fecha_Certificacion'],right_on=['Fecha_Certificacion'],how="left")

# %%
df_demanda_oec[['id_oec','id_perfil','id_fecha','num_cer']]
df_demanda_oec.to_csv(path_datawarehouse+path_datamart_oec+'/demanda_oec.csv',index=False)

# %%
data_fecha = df_fecha['Fecha_Certificacion'].str.rsplit("-", expand=True)
df_fecha = pd.concat([df_fecha,data_fecha],axis=1)

# %%
df_fecha = df_fecha.drop('Fecha_Certificacion',axis=1)

# %%
df_fecha = df_fecha.rename(columns={0:'dia',1:'mes',2:'año'})
df_fecha.to_csv(path_datawarehouse+path_datamart_oec+'/fecha.csv',index=False)

# %%
df_demanda_oec = df_pcoec.groupby(['OEC','Perfil','Fecha_Certificacion']).count().reset_index().iloc[:,:4]
df_demanda_oec = df_demanda_oec.rename(columns={'Nombres':'num_cer'})
df_demanda_oec = pd.merge(df_demanda_oec,df_razon_social_oec,left_on=['OEC'],right_on=['nombre_oec'],how="left")
df_demanda_oec = pd.merge(df_demanda_oec,df_perfil,left_on=['OEC','Perfil'],right_on=['Razon_Social','Perfil'],how="left")
df_demanda_oec = df_demanda_oec[['id_oec','id_perfil','Fecha_Certificacion','num_cer']]
df_demanda_oec.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-111-3fa808f0aabf> in <module>
#       1 df_demanda_oec = df_pcoec.groupby(['OEC','Perfil','Fecha_Certificacion']).count().reset_index().iloc[:,:4]
#       2 df_demanda_oec = df_demanda_oec.rename(columns={'Nombres':'num_cer'})
# ----> 3 df_demanda_oec = pd.merge(df_demanda_oec,df_razon_social_oec,left_on=['OEC'],right_on=['nombre_oec'],how="left")
#       4 df_demanda_oec = pd.merge(df_demanda_oec,df_perfil,left_on=['OEC','Perfil'],right_on=['Razon_Social','Perfil'],how="left")
#       5 df_demanda_oec = df_demanda_oec[['id_oec','id_perfil','Fecha_Certificacion','num_cer']]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
#     701         # validate the merge keys dtypes. We may need to coerce
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1094                     if not is_rkey(rk):
#    1095                         if rk is not None:
# -> 1096                             right_keys.append(right._get_label_or_level_values(rk))
#    1097                         else:
#    1098                             # work-around for merge_asof(right_index=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'nombre_oec'

# %% [markdown]
# # Dataframe CI

# %%
os.mkdir(path_datawarehouse+path_datamart_ci,0o666)

# %%
df_capacitador_ci = pd.read_csv(path+'CI_Provincia_Canton.csv')
df_capacitador_ci = df_capacitador_ci.rename(columns={'Nombre':'razon_social_ci'})
df_capacitador_ci  = df_capacitador_ci.rename_axis('id_ci').reset_index().astype('object')
df_capacitador_ci
# Out:
#      id_ci                        razon_social_ci   Provincia        Cantón
# 0        0           ABATA CARRERA GLORIA BEATRIZ  ESMERALDAS    ESMERALDAS
# 1        1           ABATA CARRERA GLORIA BEATRIZ  ESMERALDAS    ESMERALDAS
# 2        2                ABRIL VELEZ ERIKA LUCIA   PICHINCHA  PUERTO QUITO
# 3        3           ACOSTA CAMINO DIEGO FERNANDO  TUNGURAHUA        AMBATO
# 4        4          ACOSTA CORDOVA ANDRES EDUARDO   PICHINCHA         QUITO
# ...    ...                                    ...         ...           ...
# 1614  1614               ZHIÑA VILLA DARIO XAVIER       AZUAY        CUENCA
# 1615  1615         ZORRILLA CERTUCHE MARIO ANDRES   PICHINCHA         QUITO
# 1616  1616          ZUMARRAGA PROAÑO BERTHA OLIVA   PICHINCHA         QUITO
# 1617  1617           ZURIAGA ANCHUNDIA MARIA JOSE    LOS RIOS       QUEVEDO
# 1618  1618  ZURITA TINTA MONICA YASMIN DEL CARMEN   PICHINCHA     RUMIÑAHUI
#
# [1619 rows x 4 columns]

# %%
df_ci_lca = pd.read_csv(path+'ci_lca.csv')
df_ci_lca =  df_ci_lca.rename_axis('id_curso').reset_index().astype('object')
df_ci_lca
# Out:
#      id_curso Numero_Documento                    Apellidos_Nombres  \
# 0           0        914804364  VALENZUELA MENDIETA RICHARD OSWALDO
# 1           1        914804364  VALENZUELA MENDIETA RICHARD OSWALDO
# 2           2       1710803394          PEREZ SISA FERNANDO GUSTAVO
# 3           3       1710803394          PEREZ SISA FERNANDO GUSTAVO
# 4           4        104364112           PEÑA ENCALADA PABLO ANDRES
# ...       ...              ...                                  ...
# 2929     2929        803114982          VELASCO CAICEDO CARLOS LUIS
# 2930     2930       1803947769        ALDAS SALAZAR DARWIN SANTIAGO
# 2931     2931        922329057           MARQUEZ DIAZ KARINA MONICA
# 2932     2932        922329057           MARQUEZ DIAZ KARINA MONICA
# 2933     2933       1900495902      TENECELA GONZALEZ FRANKLIN JOSE
#
#                                            Nombre_Curso  \
# 0                       PREVENCIÓN DE RIESGOS LABORALES
# 1     INDICADORES DEL SISTEMA DE GESTIÓN DE LA SEGUR...
# 2                                   ANÁLISIS FINANCIERO
# 3       GESTIÓN FINANCIERA Y PRESUPUESTARIA EMPRESARIAL
# 4                CUIDADOS TERAPÉUTICOS DEL ADULTO MAYOR
# ...                                                 ...
# 2929                                 REVIT ARQUITECTURA
# 2930  USO DE NORMAS APA EN INVESTIGACIONES CIENTÍFIC...
# 2931                             DERECHO ADMINISTRATIVO
# 2932  DERECHOS HUMANOS CON ÉNFASIS EN PROTECCIÓN INT...
# 2933                    PREVENCIÓN DE RIESGOS LABORALES
#
#                                               Area  \
# 0                            PROCESOS INDUSTRIALES
# 1                            PROCESOS INDUSTRIALES
# 2                       FINANZAS COMERCIO Y VENTAS
# 3                       FINANZAS COMERCIO Y VENTAS
# 4       SERVICIOS SOCIOCULTURALES Y A LA COMUNIDAD
# ...                                            ...
# 2929                CONSTRUCCIÓN E INFRAESTRUCTURA
# 2930  TECNOLOGÍAS DE LA INFORMACIÓN Y COMUNICACIÓN
# 2931                  ADMINISTRACIÓN Y LEGISLACIÓN
# 2932                  ADMINISTRACIÓN Y LEGISLACIÓN
# 2933                         PROCESOS INDUSTRIALES
#
#                                            Especialidad Carga Horaria
# 0     SEGURIDAD PREVENCIÓN DE RIESGOS E HIGIENE INDU...          16.0
# 1     SEGURIDAD PREVENCIÓN DE RIESGOS E HIGIENE INDU...          40.0
# 2                                     RIESGO FINANCIERO          40.0
# 3                                     RIESGO FINANCIERO          40.0
# 4                                      SALUD Y MEDICINA          40.0
# ...                                                 ...           ...
# 2929                      TECNOLOGÍA DE LA CONSTRUCCIÓN          40.0
# 2930                            PROGRAMAS DE ESCRITORIO          24.0
# 2931                                        LEGISLACIÓN          40.0
# 2932                                        LEGISLACIÓN          32.0
# 2933  SEGURIDAD PREVENCIÓN DE RIESGOS E HIGIENE INDU...          16.0
#
# [2934 rows x 7 columns]

# %%
df_pcci = pd.read_csv(path+'pcci.csv')
df_pcci = df_pcci.groupby(['Instructor_Capacitador','Nombre_Curso']).count().reset_index()[['Instructor_Capacitador','Nombre_Curso','Numero_Documento']]
df_pcci = df_pcci.rename(columns={'Numero_Documento':'num_cap'})
df_pcci = pd.merge(df_pcci,df_capacitador_ci,left_on=['Instructor_Capacitador'],right_on=['razon_social_ci'],how="left")
df_pcci = pd.merge(df_pcci,df_ci_lca,left_on=['Instructor_Capacitador','Nombre_Curso'],right_on=['Apellidos_Nombres','Nombre_Curso'],how="left")
demanda_ci = df_pcci[['id_ci','id_curso','num_cap']]

# %%
demanda_ci.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2686 entries, 0 to 2685
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id_ci     1788 non-null   object
#  1   id_curso  1937 non-null   object
#  2   num_cap   2686 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 83.9+ KB

# %%
df_capacitador_ci.to_csv(path_datawarehouse+path_datamart_ci+'/razon_social_ci.csv',index=False)
df_ci_lca.to_csv(path_datawarehouse+path_datamart_ci+'/curso_ci.csv',index=False)
demanda_ci.to_csv(path_datawarehouse+path_datamart_ci+'/demanda_ci.csv',index=False)
